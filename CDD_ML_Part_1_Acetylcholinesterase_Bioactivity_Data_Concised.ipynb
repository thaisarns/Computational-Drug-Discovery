# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.9/site-packages (0.10.8)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.9/site-packages (from chembl_webresource_client) (2.28.1)
# Requirement already satisfied: easydict in /usr/local/lib/python3.9/site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/site-packages (from chembl_webresource_client) (1.26.10)
# Requirement already satisfied: requests-cache~=0.7.0 in /usr/local/lib/python3.9/site-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->chembl_webresource_client) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->chembl_webresource_client) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.9/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.9/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.9/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: attrs<22.0,>=21.2 in /usr/local/lib/python3.9/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...
# 1                                                  []
# 2                                                  []
# 3   [{'xref_id': 'P04058', 'xref_name': None, 'xre...
# 4   [{'xref_id': 'P21836', 'xref_name': None, 'xre...
# 5   [{'xref_id': 'P37136', 'xref_name': None, 'xre...
# 6   [{'xref_id': 'O42275', 'xref_name': None, 'xre...
# 7   [{'xref_id': 'P23795', 'xref_name': None, 'xre...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15  [{'xref_id': 'Q95P20', 'xref_name': None, 'xre...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
#
#                      organism  \
# 0                Homo sapiens
# 1                Homo sapiens
# 2     Drosophila melanogaster
# 3         Torpedo californica
# 4                Mus musculus
# 5           Rattus norvegicus
# 6    Electrophorus electricus
# 7                  Bos taurus
# 8           Anopheles gambiae
# 9              Bemisia tabaci
# 10  Leptinotarsa decemlineata
# 11     Nephotettix cincticeps
# 12              Gallus gallus
# 13                Danio rerio
# 14              Aedes aegypti
# 15            Musca domestica
# 16        Plutella xylostella
# 17            Musca domestica
# 18  Pediculus humanus capitis
# 19          Spodoptera litura
# 20      Laodelphax striatella
# 21        Schizaphis graminum
# 22     Caenorhabditis elegans
# 23          Rattus norvegicus
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   27.0
# 1                        Cholinesterases; ACHE & BCHE   27.0
# 2                                Acetylcholinesterase   17.0
# 3                                Acetylcholinesterase   15.0
# 4                                Acetylcholinesterase   15.0
# 5                                Acetylcholinesterase   15.0
# 6                                Acetylcholinesterase   15.0
# 7                                Acetylcholinesterase   15.0
# 8                                Acetylcholinesterase   15.0
# 9                                               AChE2   15.0
# 10                               Acetylcholinesterase   15.0
# 11               Ace-orthologous acetylcholinesterase   15.0
# 12                               Acetylcholinesterase   15.0
# 13                               Acetylcholinesterase   15.0
# 14                               Acetylcholinesterase   15.0
# 15                               Acetylcholinesterase   14.0
# 16                               Acetylcholinesterase   14.0
# 17                               Acetylcholinesterase   14.0
# 18                               Acetylcholinesterase   14.0
# 19                               Acetylcholinesterase   14.0
# 20                               Acetylcholinesterase   14.0
# 21                               Acetylcholinesterase   14.0
# 22                             Acetylcholinesterase 1   14.0
# 23  Acetylcholinesterase and butyrylcholinesterase...   13.0
#
#     species_group_flag target_chembl_id  \
# 0                False        CHEMBL220
# 1                False    CHEMBL2095233
# 2                False    CHEMBL2242744
# 3                False       CHEMBL4780
# 4                False       CHEMBL3198
# 5                False       CHEMBL3199
# 6                False       CHEMBL4078
# 7                False       CHEMBL4768
# 8                False    CHEMBL2046266
# 9                False    CHEMBL2366409
# 10               False    CHEMBL2366490
# 11               False    CHEMBL2366514
# 12               False    CHEMBL3227914
# 13               False    CHEMBL3308995
# 14               False    CHEMBL4295607
# 15               False       CHEMBL5752
# 16               False    CHEMBL2242729
# 17               False    CHEMBL2242743
# 18               False    CHEMBL2362988
# 19               False    CHEMBL2366422
# 20               False    CHEMBL2366446
# 21               False    CHEMBL2366511
# 22               False    CHEMBL3341583
# 23               False    CHEMBL2111475
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 2   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 15  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 17  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
# 23  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
#
#     tax_id
# 0     9606
# 1     9606
# 2     7227
# 3     7787
# 4    10090
# 5    10116
# 6     8005
# 7     9913
# 8     7165
# 9     7038
# 10    7539
# 11   94400
# 12    9031
# 13    7955
# 14    7159
# 15    7370
# 16   51655
# 17    7370
# 18  121226
# 19   69820
# 20  195883
# 21   13262
# 22    6239
# 23   10116

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3198'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None        72527                  []    CHEMBL638608
# 1               None        73586                  []    CHEMBL638608
# 2               None        74599                  []    CHEMBL638608
# 3               None        75755                  []    CHEMBL638608
# 4               None        76879                  []    CHEMBL638608
# ..               ...          ...                 ...             ...
# 524             None     19449586                  []   CHEMBL4433439
# 525             None     19449587                  []   CHEMBL4433439
# 526             None     19449588                  []   CHEMBL4433439
# 527             None     19449589                  []   CHEMBL4433439
# 528             None     19449590                  []   CHEMBL4433439
#
#                                      assay_description assay_type  \
# 0     Inhibitory activity against acetylcholinesterase          B
# 1     Inhibitory activity against acetylcholinesterase          B
# 2     Inhibitory activity against acetylcholinesterase          B
# 3     Inhibitory activity against acetylcholinesterase          B
# 4     Inhibitory activity against acetylcholinesterase          B
# ..                                                 ...        ...
# 524  Inhibition of mouse brain AChE using acetylthi...          B
# 525  Inhibition of mouse brain AChE using acetylthi...          B
# 526  Inhibition of mouse brain AChE using acetylthi...          B
# 527  Inhibition of mouse brain AChE using acetylthi...          B
# 528  Inhibition of mouse brain AChE using acetylthi...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0000190  BAO_0000357
# 1                      None                   None  BAO_0000190  BAO_0000357
# 2                      None                   None  BAO_0000190  BAO_0000357
# 3                      None                   None  BAO_0000190  BAO_0000357
# 4                      None                   None  BAO_0000190  BAO_0000357
# ..                      ...                    ...          ...          ...
# 524                    None                   None  BAO_0000190  BAO_0000019
# 525                    None                   None  BAO_0000190  BAO_0000019
# 526                    None                   None  BAO_0000190  BAO_0000019
# 527                    None                   None  BAO_0000190  BAO_0000019
# 528                    None                   None  BAO_0000190  BAO_0000019
#
#      ... target_organism      target_pref_name target_tax_id text_value  toid  \
# 0    ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 1    ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 2    ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 3    ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 4    ...    Mus musculus  Acetylcholinesterase         10090       None  None
# ..   ...             ...                   ...           ...        ...   ...
# 524  ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 525  ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 526  ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 527  ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 528  ...    Mus musculus  Acetylcholinesterase         10090       None  None
#
#      type  units    uo_units upper_value   value
# 0    IC50     nM  UO_0000065        None     5.7
# 1    IC50     nM  UO_0000065        None    13.0
# 2    IC50     nM  UO_0000065        None     1.5
# 3    IC50     nM  UO_0000065        None  2100.0
# 4    IC50     nM  UO_0000065        None  4400.0
# ..    ...    ...         ...         ...     ...
# 524  IC50     uM  UO_0000065        None    50.0
# 525  IC50     uM  UO_0000065        None    22.6
# 526  IC50     uM  UO_0000065        None    0.71
# 527  IC50     uM  UO_0000065        None    9.47
# 528  IC50     uM  UO_0000065        None    3.98
#
# [529 rows x 45 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /var/folders/j0/1d56kktn69z2xnhstmgtlttr0000gq/T/ipykernel_7739/3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None        72527                  []    CHEMBL638608
# 1               None        73586                  []    CHEMBL638608
# 2               None        74599                  []    CHEMBL638608
# 3               None        75755                  []    CHEMBL638608
# 4               None        76879                  []    CHEMBL638608
# ..               ...          ...                 ...             ...
# 524             None     19449586                  []   CHEMBL4433439
# 525             None     19449587                  []   CHEMBL4433439
# 526             None     19449588                  []   CHEMBL4433439
# 527             None     19449589                  []   CHEMBL4433439
# 528             None     19449590                  []   CHEMBL4433439
#
#                                      assay_description assay_type  \
# 0     Inhibitory activity against acetylcholinesterase          B
# 1     Inhibitory activity against acetylcholinesterase          B
# 2     Inhibitory activity against acetylcholinesterase          B
# 3     Inhibitory activity against acetylcholinesterase          B
# 4     Inhibitory activity against acetylcholinesterase          B
# ..                                                 ...        ...
# 524  Inhibition of mouse brain AChE using acetylthi...          B
# 525  Inhibition of mouse brain AChE using acetylthi...          B
# 526  Inhibition of mouse brain AChE using acetylthi...          B
# 527  Inhibition of mouse brain AChE using acetylthi...          B
# 528  Inhibition of mouse brain AChE using acetylthi...          B
#
#     assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                      None                   None  BAO_0000190  BAO_0000357
# 1                      None                   None  BAO_0000190  BAO_0000357
# 2                      None                   None  BAO_0000190  BAO_0000357
# 3                      None                   None  BAO_0000190  BAO_0000357
# 4                      None                   None  BAO_0000190  BAO_0000357
# ..                      ...                    ...          ...          ...
# 524                    None                   None  BAO_0000190  BAO_0000019
# 525                    None                   None  BAO_0000190  BAO_0000019
# 526                    None                   None  BAO_0000190  BAO_0000019
# 527                    None                   None  BAO_0000190  BAO_0000019
# 528                    None                   None  BAO_0000190  BAO_0000019
#
#      ... target_organism      target_pref_name target_tax_id text_value  toid  \
# 0    ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 1    ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 2    ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 3    ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 4    ...    Mus musculus  Acetylcholinesterase         10090       None  None
# ..   ...             ...                   ...           ...        ...   ...
# 524  ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 525  ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 526  ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 527  ...    Mus musculus  Acetylcholinesterase         10090       None  None
# 528  ...    Mus musculus  Acetylcholinesterase         10090       None  None
#
#      type  units    uo_units upper_value   value
# 0    IC50     nM  UO_0000065        None     5.7
# 1    IC50     nM  UO_0000065        None    13.0
# 2    IC50     nM  UO_0000065        None     1.5
# 3    IC50     nM  UO_0000065        None  2100.0
# 4    IC50     nM  UO_0000065        None  4400.0
# ..    ...    ...         ...         ...     ...
# 524  IC50     uM  UO_0000065        None    50.0
# 525  IC50     uM  UO_0000065        None    22.6
# 526  IC50     uM  UO_0000065        None    0.71
# 527  IC50     uM  UO_0000065        None    9.47
# 528  IC50     uM  UO_0000065        None    3.98
#
# [523 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv

# %%
! ls -l

# %% [markdown]
# ---
